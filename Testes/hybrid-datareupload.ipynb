# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder
#import os
#os.environ["OMP_NUM_THREADS"] = "8"
N_QUBITS = 8
df_data = pd.read_csv('features_cleaned.csv')

X = df_data.drop(columns=['class', 'image_name'])

y = df_data['class']

#pca = PCA(n_components=N_QUBITS)
#X_pca= pca.fit_transform(X)  

print(X.shape)
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

#X_final = X_pca.copy()


# 2. Normaliza para [0, π] 
# scaler = MinMaxScaler()
scaler = MinMaxScaler(feature_range=(0, np.pi))
X_scaled = scaler.fit_transform(X)


classes_existentes = sorted(y.unique()) 
n_classes = len(classes_existentes)



X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y , test_size=0.9, random_state=42, stratify=y
)


print("X_train shape:", X_train.shape)  
print("X_test shape: ", X_test.shape)   
print("Primeira amostra:", X_train[0])
# Out:
# (43699, 42)
# X_train shape: (4369, 42)
# X_test shape:  (39330, 42)
# Primeira amostra: [0.         0.         0.88580849 0.59489987 0.86035048 0.50427714
#  1.04568886 0.44227969 1.16187705 0.37634726 1.16186893 0.28360425
#  1.10873369 0.3967888  1.11185766 0.64112754 1.14612691 0.82817593
#  1.30952645 0.02047733 1.35995138 0.09247442 1.37319485 0.13221537
#  1.39299614 0.19566391 1.47587466 0.04942785 1.4258501  0.09038858
#  1.63542897 0.11241429 1.65064918 0.16552461 1.66686162 0.23854062
#  1.58994522 0.18817917 1.83205169 0.22109875 1.81567116 0.2652958 ]

# %%
print(pca.explained_variance_ratio_.cumsum())

# %%
from math import ceil
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector

num_features = 42
num_qubits = 8

data_vector = ParameterVector("x", num_features)

def build_data_reupload_only(num_qubits, num_features, data_vector):
    qc = QuantumCircuit(num_qubits)

    num_reuploads = ceil(num_features / num_qubits)
    feature_idx = 0

    for layer in range(num_reuploads):
        for q in range(num_qubits):
            if feature_idx < num_features:
                qc.ry(data_vector[feature_idx], q)
                feature_idx += 1

        for q in range(num_qubits - 1):
            qc.cz(q, q + 1)

        qc.barrier()

    return qc

reupload = build_data_reupload_only(
    num_qubits=num_qubits,
    num_features=num_features,
    data_vector=data_vector
)

reupload.draw("mpl")

# %%
pip install pylatexenc

# %%
from qiskit.circuit.library import RealAmplitudes
from qiskit import QuantumCircuit
from qiskit.circuit.library import ZZFeatureMap
import json
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.circuit.library import ZZFeatureMap, RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import StatevectorEstimator as Estimator
from qiskit_machine_learning.optimizers import COBYLA
from qiskit_machine_learning.utils import algorithm_globals
from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier
from qiskit_machine_learning.neural_networks import EstimatorQNN, SamplerQNN
from sklearn.model_selection import train_test_split


num_features = 8       
print(f"Usando {num_features} qubits")


feature_map = ZZFeatureMap(num_features, reps=1)


ansatz =  RealAmplitudes(num_features, reps=1) 


qc = QuantumCircuit(num_features)
qc.compose(reupload, inplace=True)
qc.compose(ansatz.decompose(), inplace=True)


qc.draw("mpl", fold=-1)
# Out:
# Usando 8 qubits
# C:\Users\Richard\AppData\Local\Temp\ipykernel_17164\1558085222.py:24: DeprecationWarning: The class ``qiskit.circuit.library.data_preparation._zz_feature_map.ZZFeatureMap`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the zz_feature_map function as a replacement. Note that this will no longer return a BlueprintCircuit, but just a plain QuantumCircuit.
#   feature_map = ZZFeatureMap(num_features, reps=1)
# C:\Users\Richard\AppData\Local\Temp\ipykernel_17164\1558085222.py:27: DeprecationWarning: The class ``qiskit.circuit.library.n_local.real_amplitudes.RealAmplitudes`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the function qiskit.circuit.library.real_amplitudes instead.
#   ansatz =  RealAmplitudes(num_features, reps=1)

# %%
from qiskit.quantum_info import Pauli
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit.primitives import StatevectorEstimator
#from qiskit_aer.primitives import Estimator as AerEstimator

#FOR 8 QUBITS
observables = [
    Pauli("ZIIIIIII"),
    Pauli("IZIIIIII"),
    Pauli("IIZIIIII"),
    Pauli("IIIZIIII"),
    Pauli("IIIIZIII"),
    Pauli("IIIIIZII"),
    Pauli("IIIIIIZI"),
    Pauli("IIIIIIIZ"),
]
# observables = [
#     Pauli("ZIIIII"),
#     Pauli("IZIIII"),
#     Pauli("IIZIII"),
#     Pauli("IIIZII"),
#     Pauli("IIIIZI"),
#     Pauli("IIIIIZ"),
# ]

from qiskit_aer.primitives import EstimatorV2 as AerEstimator
estimator = AerEstimator(
    options={
        "backend_options": {
            "method": "statevector",
            "device": "CPU",
            "precision": "double",
            "max_parallel_threads": 16,
            "max_parallel_experiments": 0,
            "blocking_enable": False,
        }
    }
)
qnn = EstimatorQNN(
    circuit=qc,
    input_params=list(data_vector),
    weight_params=ansatz.parameters,
    observables=observables,
    estimator=estimator,
)
# Out:
# No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.

# %%
from qiskit_machine_learning.connectors import TorchConnector
import torch
import torch.nn as nn


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

quantum_layer = TorchConnector(qnn)

# %%
class HybridModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.quantum = quantum_layer
        self.classical = nn.Sequential(
            nn.Linear(N_QUBITS, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 21)
        )
        
    def forward(self, x):
        x = self.quantum(x)
        x = self.classical(x)
        return x

# %%
from sklearn.utils import resample

X_train_small, y_train_small = resample(
    X_train, y_train,
    n_samples=5000,
    stratify=y_train,  # keeps class balance
    random_state=42
)

# %%
from sklearn.utils.class_weight import compute_class_weight

X_tensor = torch.tensor(X_train_small, dtype=torch.float32)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y_train_small) #necessário para não dar erro de string


y_tensor = torch.tensor(y_encoded, dtype=torch.long)

from torch.utils.data import TensorDataset, DataLoader

dataset = TensorDataset(X_tensor, y_tensor)
loader = DataLoader(
    dataset,
    batch_size=128,
    shuffle=True,
    num_workers=4,
)

model = HybridModel()

# Class weights to handle imbalanced classes
weights = compute_class_weight('balanced', classes=np.unique(y_encoded), y=y_encoded)
criterion = nn.CrossEntropyLoss(weight=torch.tensor(weights, dtype=torch.float32))

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001,
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', patience=3, factor=0.5
)

# %%
epochs = 30
torch.set_num_threads(8)

for epoch in range(epochs):
    total_loss = 0
    loaders = 0
    
    for xb, yb in loader:

        print(f"Inicio iteração para {len(loader)} loaders. Restam {(len(loader) - loaders)}")
        optimizer.zero_grad()
        
        outputs = model(xb)
        loss = criterion(outputs, yb)
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        print(f"Loss até aqui: {total_loss/len(loader)}")

        loaders = loaders + 1 
    
    avg_loss = total_loss / len(loader)
    scheduler.step(avg_loss)
    
    print(f"Fim de Epoch {epoch+1}, Loss: {avg_loss}, LR: {optimizer.param_groups[0]['lr']}")
# Out:
# Inicio iteração para 40 loaders. Restam 40
# Loss até aqui: 0.0760562002658844
# Inicio iteração para 40 loaders. Restam 39
# Loss até aqui: 0.1516392469406128
# Inicio iteração para 40 loaders. Restam 38
# Loss até aqui: 0.22678223252296448
# Inicio iteração para 40 loaders. Restam 37
# Loss até aqui: 0.3014619529247284
# Inicio iteração para 40 loaders. Restam 36
# Loss até aqui: 0.37596166133880615
# Inicio iteração para 40 loaders. Restam 35
# Loss até aqui: 0.45106655955314634
# Inicio iteração para 40 loaders. Restam 34
# Loss até aqui: 0.5250329911708832
# Inicio iteração para 40 loaders. Restam 33
# Loss até aqui: 0.5986529171466828
# Inicio iteração para 40 loaders. Restam 32
# Loss até aqui: 0.6711164593696595
# Inicio iteração para 40 loaders. Restam 31
# Loss até aqui: 0.7435298085212707
# Inicio iteração para 40 loaders. Restam 30
# Loss até aqui: 0.815521878004074
# Inicio iteração para 40 loaders. Restam 29
# Loss até aqui: 0.8871048212051391
# Inicio iteração para 40 loaders. Restam 28
# Loss até aqui: 0.9592667102813721
# Inicio iteração para 40 loaders. Restam 27
# Loss até aqui: 1.0299074172973632
# Inicio iteração para 40 loaders. Restam 26
# Loss até aqui: 1.1007383942604065
# Inicio iteração para 40 loaders. Restam 25
# Loss até aqui: 1.1709785640239716
# Inicio iteração para 40 loaders. Restam 24
# Loss até aqui: 1.2411688983440399
# Inicio iteração para 40 loaders. Restam 23
# Loss até aqui: 1.3095135152339936
# Inicio iteração para 40 loaders. Restam 22
# Loss até aqui: 1.37798113822937
# Inicio iteração para 40 loaders. Restam 21
# Loss até aqui: 1.4460035681724548
# Inicio iteração para 40 loaders. Restam 20
# Loss até aqui: 1.5127507448196411
# Inicio iteração para 40 loaders. Restam 19
# Loss até aqui: 1.579028421640396
# Inicio iteração para 40 loaders. Restam 18
# Loss até aqui: 1.6447471618652343
# Inicio iteração para 40 loaders. Restam 17
# Loss até aqui: 1.710605937242508
# Inicio iteração para 40 loaders. Restam 16
# Loss até aqui: 1.7768516421318055
# Inicio iteração para 40 loaders. Restam 15
# Loss até aqui: 1.8411183774471283
# Inicio iteração para 40 loaders. Restam 14
# Loss até aqui: 1.9050696432590484
# Inicio iteração para 40 loaders. Restam 13
# Loss até aqui: 1.9684881091117858
# Inicio iteração para 40 loaders. Restam 12
# Loss até aqui: 2.03186953663826
# Inicio iteração para 40 loaders. Restam 11
# Loss até aqui: 2.0950345754623414
# Inicio iteração para 40 loaders. Restam 10
# Loss até aqui: 2.1575851678848266
# Inicio iteração para 40 loaders. Restam 9
# Loss até aqui: 2.2213807582855223
# Inicio iteração para 40 loaders. Restam 8
# Loss até aqui: 2.282995480298996
# Inicio iteração para 40 loaders. Restam 7
# Loss até aqui: 2.3430793642997743
# Inicio iteração para 40 loaders. Restam 6
# Loss até aqui: 2.4035232067108154
# Inicio iteração para 40 loaders. Restam 5
# Loss até aqui: 2.464021992683411
# Inicio iteração para 40 loaders. Restam 4
# Loss até aqui: 2.5225759744644165
# Inicio iteração para 40 loaders. Restam 3
# Loss até aqui: 2.5801614105701445
# Inicio iteração para 40 loaders. Restam 2
# Loss até aqui: 2.6405230104923247
# Inicio iteração para 40 loaders. Restam 1
# Loss até aqui:
# Inicio iteração para 40 loaders. Restam 8
# Loss até aqui: 0.23188916146755217
# Inicio iteração para 40 loaders. Restam 7
# Loss até aqui: 0.24106520265340806
# Inicio iteração para 40 loaders. Restam 6
# Loss até aqui: 0.2488494485616684
# Inicio iteração para 40 loaders. Restam 5
# Loss até aqui: 0.2556701086461544
# Inicio iteração para 40 loaders. Restam 4
# Loss até aqui: 0.2618121366947889
# Inicio iteração para 40 loaders. Restam 3
# Loss até aqui: 0.26812156178057195
# Inicio iteração para 40 loaders. Restam 2
# Loss até aqui: 0.27583740316331384
# Inicio iteração para 40 loaders. Restam 1
# Loss até aqui: 0.29365478120744226
# Fim de Epoch 27, Loss: 0.29365478120744226, LR: 0.001
# Inicio iteração para 40 loaders. Restam 40
# Loss até aqui: 0.005997182056307793
# Inicio iteração para 40 loaders. Restam 39
# Loss até aqui: 0.01262594796717167
# Inicio iteração para 40 loaders. Restam 38
# Loss até aqui: 0.018698028475046157
# Inicio iteração para 40 loaders. Restam 37
# Loss até aqui: 0.022970912232995033
# Inicio iteração para 40 loaders. Restam 36
# Loss até aqui: 0.027843761816620828
# Inicio iteração para 40 loaders. Restam 35
# Loss até aqui: 0.03562780283391476
# Inicio iteração para 40 loaders. Restam 34
# Loss até aqui: 0.043970615789294246
# Inicio iteração para 40 loaders. Restam 33
# Loss até aqui: 0.05104770623147488
# Inicio iteração para 40 loaders. Restam 32
# Loss até aqui: 0.06020279489457607
# Inicio iteração para 40 loaders. Restam 31
# Loss até aqui: 0.0664081010967493
# Inicio iteração para 40 loaders. Restam 30
# Loss até aqui: 0.07160621955990791
# Inicio iteração para 40 loaders. Restam 29
# Loss até aqui: 0.07957246080040932
# Inicio iteração para 40 loaders. Restam 28
# Loss até aqui: 0.08581938855350017
# Inicio iteração para 40 loaders. Restam 27
# Loss até aqui: 0.09238824360072613
# Inicio iteração para 40 loaders. Restam 26
# Loss até aqui: 0.10036287643015385
# Inicio iteração para 40 loaders. Restam 25
# Loss até aqui: 0.10530992820858956
# Inicio iteração para 40 loaders. Restam 24
# Loss até aqui: 0.1114752721041441
# Inicio iteração para 40 loaders. Restam 23
# Loss até aqui: 0.11724867187440395
# Inicio iteração para 40 loaders. Restam 22
# Loss até aqui: 0.12407712303102017
# Inicio iteração para 40 loaders. Restam 21
# Loss até aqui: 0.13254511915147305
# Inicio iteração para 40 loaders. Restam 20
# Loss até aqui: 0.13940860666334629
# Inicio iteração para 40 loaders. Restam 19
# Loss até aqui: 0.14406825974583626
# Inicio iteração para 40 loaders. Restam 18
# Loss até aqui: 0.15193371921777726
# Inicio iteração para 40 loaders. Restam 17
# Loss até aqui: 0.1572176270186901
# Inicio iteração para 40 loaders. Restam 16
# Loss até aqui: 0.1629763126373291
# Inicio iteração para 40 loaders. Restam 15
# Loss até aqui: 0.1690556552261114
# Inicio iteração para 40 loaders. Restam 14
# Loss até aqui: 0.17660499997437
# Inicio iteração para 40 loaders. Restam 13
# Loss até aqui: 0.18338026739656926
# Inicio iteração para 40 loaders. Restam 12
# Loss até aqui: 0.19118801467120647
# Inicio iteração para 40 loaders. Restam 11
# Loss até aqui: 0.19649586863815785
# Inicio iteração para 40 loaders. Restam 10
# Loss até aqui: 0.2051211442798376
# Inicio iteração para 40 loaders. Restam 9
# Loss até aqui: 0.2120311800390482
# Inicio iteração para 40 loaders. Restam 8
# Loss até aqui: 0.2175814438611269
# Inicio iteração para 40 loaders. Restam 7
# Loss até aqui: 0.22324423678219318
# Inicio iteração para 40 loaders. Restam 6
# Loss até aqui: 0.23057073839008807
# Inicio iteração para 40 loaders. Restam 5
# Loss até aqui: 0.2366572331637144
# Inicio iteração para 40 loaders. Restam 4
# Loss até aqui: 0.2429867971688509
# Inicio iteração para 40 loaders. Restam 3
# Loss até aqui: 0.2502665612846613
# Inicio iteração para 40 loaders. Restam 2
# Loss até aqui: 0.2586277391761541
# Inicio iteração para 40 loaders. Restam 1
# Loss até aqui: 0.2747864808887243
# Fim de Epoch 28, Loss: 0.2747864808887243, LR: 0.001
# Inicio iteração para 40 loaders. Restam 40
# Loss até aqui: 0.006561470031738281
# Inicio iteração para 40 loaders. Restam 39
# Loss até aqui: 0.01391354501247406
# Inicio iteração para 40 loaders. Restam 38
# Loss até aqui: 0.022037789225578308
# Inicio iteração para 40 loaders. Restam 37
# Loss até aqui: 0.028932031989097596
# Inicio iteração para 40 loaders. Restam 36
# Loss até aqui: 0.03640025109052658
# Inicio iteração para 40 loaders. Restam 35
# Loss até aqui: 0.041070972383022306
# Inicio iteração para 40 loaders. Restam 34
# Loss até aqui: 0.04770444333553314
# Inicio iteração para 40 loaders. Restam 33
# Loss até aqui: 0.05393748469650746
# Inicio iteração para 40 loaders. Restam 32
# Loss até aqui: 0.060526196286082266
# Inicio iteração para 40 loaders. Restam 31
# Loss até aqui: 0.06803882755339145
# Inicio iteração para 40 loaders. Restam 30
# Loss até aqui: 0.07512681819498539
# Inicio iteração para 40 loaders. Restam 29
# Loss até aqui: 0.08330566696822643
# Inicio iteração para 40 loaders. Restam 28
# Loss até aqui: 0.0909034837037325
# Inicio iteração para 40 loaders. Restam 27
# Loss até aqui: 0.09705323241651058
# Inicio iteração para 40 loaders. Restam 26
# Loss até aqui: 0.1039656538516283
# Inicio iteração para 40 loaders. Restam 25
# Loss até aqui: 0.11377640776336193
# Inicio iteração para 40 loaders. Restam 24
# Loss até aqui: 0.12047003693878651
# Inicio iteração para 40 loaders. Restam 23
# Loss até aqui: 0.12839759103953838
# Inicio iteração para 40 loaders. Restam 22
# Loss até aqui: 0.13491832427680492
# Inicio iteração para 40 loaders. Restam 21
# Loss até aqui: 0.14027424305677413
# Inicio iteração para 40 loaders. Restam 20
# Loss até aqui: 0.1468675948679447
# Inicio iteração para 40 loaders. Restam 19
# Loss até aqui: 0.15165790133178234
# Inicio iteração para 40 loaders. Restam 18
# Loss até aqui: 0.15805867947638036
# Inicio iteração para 40 loaders. Restam 17
# Loss até aqui: 0.16471593715250493
# Inicio iteração para 40 loaders. Restam 16
# Loss até aqui: 0.17372426129877566
# Inicio iteração para 40 loaders. Restam 15
# Loss até aqui: 0.18031313680112362
# Inicio iteração para 40 loaders. Restam 14
# Loss até aqui: 0.18776072077453138
# Inicio iteração para 40 loaders. Restam 13
# Loss até aqui: 0.19425294660031794
# Inicio iteração para 40 loaders. Restam 12
# Loss até aqui: 0.19990981444716455
# Inicio iteração para 40 loaders. Restam 11
# Loss até aqui: 0.20713508352637292
# Inicio iteração para 40 loaders. Restam 10
# Loss até aqui: 0.21174868382513523
# Inicio iteração para 40 loaders. Restam 9
# Loss até aqui: 0.21897248215973378
# Inicio iteração para 40 loaders. Restam 8
# Loss até aqui: 0.22599227540194988
# Inicio iteração para 40 loaders. Restam 7
# Loss até aqui: 0.2341645535081625
# Inicio iteração para 40 loaders. Restam 6
# Loss até aqui: 0.24080346040427686
# Inicio iteração para 40 loaders. Restam 5
# Loss até aqui: 0.24549853540956973
# Inicio iteração para 40 loaders. Restam 4
# Loss até aqui: 0.2507591757923365
# Inicio iteração para 40 loaders. Restam 3
# Loss até aqui: 0.2578784566372633
# Inicio iteração para 40 loaders. Restam 2
# Loss até aqui: 0.26510319076478484
# Inicio iteração para 40 loaders. Restam 1
# Loss até aqui: 0.2806574922055006
# Fim de Epoch 29, Loss: 0.2806574922055006, LR: 0.001
# Inicio iteração para 40 loaders. Restam 40
# Loss até aqui: 0.00536968931555748
# Inicio iteração para 40 loaders. Restam 39
# Loss até aqui: 0.01172865778207779
# Inicio iteração para 40 loaders. Restam 38
# Loss até aqui: 0.01912923976778984
# Inicio iteração para 40 loaders. Restam 37
# Loss até aqui: 0.025229015201330186
# Inicio iteração para 40 loaders. Restam 36
# Loss até aqui: 0.030859435722231866
# Inicio iteração para 40 loaders. Restam 35
# Loss até aqui: 0.037063528597354886
# Inicio iteração para 40 loaders. Restam 34
# Loss até aqui: 0.0414881132543087
# Inicio iteração para 40 loaders. Restam 33
# Loss até aqui: 0.04655922874808312
# Inicio iteração para 40 loaders. Restam 32
# Loss até aqui: 0.052703219652175906
# Inicio iteração para 40 loaders. Restam 31
# Loss até aqui: 0.06048130914568901
# Inicio iteração para 40 loaders. Restam 30
# Loss até aqui: 0.07111296206712722
# Inicio iteração para 40 loaders. Restam 29
# Loss até aqui: 0.08006650432944298
# Inicio iteração para 40 loaders. Restam 28
# Loss até aqui: 0.08665127903223038
# Inicio iteração para 40 loaders. Restam 27
# Loss até aqui: 0.09256756752729416
# Inicio iteração para 40 loaders. Restam 26
# Loss até aqui: 0.09903122633695602
# Inicio iteração para 40 loaders. Restam 25
# Loss até aqui: 0.10503186807036399
# Inicio iteração para 40 loaders. Restam 24
# Loss até aqui: 0.1123703695833683
# Inicio iteração para 40 loaders. Restam 23
# Loss até aqui: 0.12130147665739059
# Inicio iteração para 40 loaders. Restam 22
# Loss até aqui: 0.12814735844731331
# Inicio iteração para 40 loaders. Restam 21
# Loss até aqui: 0.1353858694434166
# Inicio iteração para 40 loaders. Restam 20
# Loss até aqui: 0.1429039269685745
# Inicio iteração para 40 loaders. Restam 19
# Loss até aqui: 0.14938894361257554
# Inicio iteração para 40 loaders. Restam 18
# Loss até aqui: 0.15450206883251666
# Inicio iteração para 40 loaders. Restam 17
# Loss até aqui: 0.16085016764700413
# Inicio iteração para 40 loaders. Restam 16
# Loss até aqui: 0.16732859499752523
# Inicio iteração para 40 loaders. Restam 15
# Loss até aqui: 0.17358158268034457
# Inicio iteração para 40 loaders. Restam 14
# Loss até aqui: 0.18177508749067783
# Inicio iteração para 40 loaders. Restam 13
# Loss até aqui: 0.18980860747396947
# Inicio iteração para 40 loaders. Restam 12
# Loss até aqui: 0.19678248576819896
# Inicio iteração para 40 loaders. Restam 11
# Loss até aqui: 0.20247512571513654
# Inicio iteração para 40 loaders. Restam 10
# Loss até aqui: 0.20930218435823916
# Inicio iteração para 40 loaders. Restam 9
# Loss até aqui: 0.21467364057898522
# Inicio iteração para 40 loaders. Restam 8
# Loss até aqui: 0.2206043679267168
# Inicio iteração para 40 loaders. Restam 7
# Loss até aqui: 0.22718182988464833
# Inicio iteração para 40 loaders. Restam 6
# Loss até aqui: 0.23377023376524447
# Inicio iteração para 40 loaders. Restam 5
# Loss até aqui: 0.24066920764744282
# Inicio iteração para 40 loaders. Restam 4
# Loss até aqui: 0.24738021679222583
# Inicio iteração para 40 loaders. Restam 3
# Loss até aqui: 0.25328164026141164
# Inicio iteração para 40 loaders. Restam 2
# Loss até aqui: 0.26023673042654993
# Inicio iteração para 40 loaders. Restam 1
# Loss até aqui: 0.33784991726279257
# Fim de Epoch 30, Loss: 0.33784991726279257, LR: 0.001

# %%
from sklearn.metrics import classification_report

model.eval()

with torch.no_grad():
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    outputs = model(X_test_tensor)
    _, y_pred = torch.max(outputs, dim=1)
    y_pred = y_pred.numpy()

y_test_encoded = le.transform(y_test)

# Full per-class report
print(classification_report(
    y_test_encoded, 
    y_pred, 
    target_names=le.classes_  # shows original class names instead of numbers
))
# Out:
#               precision    recall  f1-score   support
#
#            A       1.00      0.98      0.99      1910
#            B       1.00      0.99      0.99      1901
#            C       0.98      0.97      0.97      1896
#            D       1.00      0.99      1.00      1881
#            E       0.99      1.00      0.99      1918
#            F       0.97      0.96      0.96      1793
#            G       0.98      1.00      0.99      1881
#            I       1.00      1.00      1.00      1881
#            L       1.00      1.00      1.00      1881
#            M       0.88      0.98      0.93      1881
#            N       0.97      0.82      0.89      1871
#            O       0.97      0.97      0.97      1742
#            P       0.97      1.00      0.99      1878
#            Q       0.95      0.98      0.97      1881
#            R       0.88      0.94      0.91      1881
#            S       0.98      1.00      0.99      1881
#            T       0.96      0.96      0.96      1850
#            U       0.93      0.87      0.90      1881
#            V       0.97      0.99      0.98      1881
#            W       1.00      0.99      0.99      1880
#            Y       1.00      0.97      0.98      1881
#
#     accuracy                           0.97     39330
#    macro avg       0.97      0.97      0.97     39330
# weighted avg       0.97      0.97      0.97     39330
